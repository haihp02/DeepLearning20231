# %%
from tokenizers import Tokenizer, models, \
    trainers, normalizers, pre_tokenizers, processors, decoders
import sentencepiece as spm

# %% [markdown]
# # Prepare corpus for training tokenizer

# %%
with open('./data/collection.tsv', 'r') as rf, open('./data/raw_texts/collection_corpus.txt', 'w') as wf:
    for line in rf.readlines():
        wf.write(line.split('\t')[1])

# %%
with open('./data/queries.train.tsv', 'r') as rf, open('./data/raw_texts/queries.train_corpus.txt', 'w') as wf:
    for line in rf.readlines():
        wf.write(line.split('\t')[1])

# %%
with open('./data/queries.dev.tsv', 'r') as rf, open('./data/raw_texts/queries.dev_corpus.txt', 'w') as wf:
    for line in rf.readlines():
        wf.write(line.split('\t')[1])

# %%
with open('./data/queries.eval.tsv', 'r') as rf, open('./data/raw_texts/queries.eval_corpus.txt', 'w') as wf:
    for line in rf.readlines():
        wf.write(line.split('\t')[1])

# %% [markdown]
# # Tokenizer training

# %% [markdown]
# ## Huggingface tokenizer

# %% [markdown]
# ### BPE tokenizer

# %%
bpe_tokenizer = Tokenizer(models.BPE())
bpe_tokenizer.normalizer = normalizers.NFC()
bpe_tokenizer.pre_tokenizer = pre_tokenizers.Whitespace()

bpe_tokenizer.decoder = decoders.WordPiece('@@')
trainer = trainers.BpeTrainer(special_tokens=[
    '[UNK]',
    '[CLS]',
    '[SEP]',
    '[PAD]'],
    unknow_token='[UNK]',
    vocab_size=32000,
    min_frequency=0,
    continuing_subword_prefix='@@')

# %%
files = [f'./data/raw_texts/{file}.txt' for file in ['collection_corpus', 'queries.train_corpus', 'queries.dev_corpus', 'queries.eval_corpus']]
bpe_tokenizer.train(files=files, trainer=trainer)

# %%
print(bpe_tokenizer.encode('Hi i am a studen. My name is Hai.').tokens)
print(bpe_tokenizer.encode('Hi i am a studen. My name is Hai.').ids)
# Out:
# ['Hi', 'i', 'am', 'a', 'stud', '@@en', '.', 'My', 'name', 'is', 'H', '@@ai', '.']
# [7390, 75, 947, 67, 1253, 591, 16, 2124, 979, 609, 42, 2523, 16]

# %%
bpe_tokenizer.decode([42, 323, 75, 947, 67, 1253, 591, 16, 2124, 979, 609, 42, 2523, 16])
# Out:
# 'Hi i am a studen. My name is Hai.'

# %% [markdown]
# ### WordPiece tokenizer

# %%
# WP tokenizer inspired by BERT tokenizer
wp_tokenizer = Tokenizer(models.WordPiece())
wp_tokenizer.normalizer = normalizers.Sequence([normalizers.NFC(),
                                                normalizers.Lowercase(),
                                                normalizers.StripAccents()])
wp_tokenizer.pre_tokenizer = pre_tokenizers.Whitespace()
wp_tokenizer.decoder = decoders.WordPiece()
wp_tokenizer.post_processor = processors.TemplateProcessing(
    single='[CLS] $A [SEP]',
    pair="[CLS] $A [SEP] $B:1 [SEP]:1",
    special_tokens=[
        ('[CLS]', 1),
        ('[SEP]', 2),
    ],
)
trainer = trainers.WordPieceTrainer(special_tokens=[
    '[UNK]',
    '[CLS]',
    '[SEP]',
    '[PAD]'],
    unknow_token='[UNK]',
    vocab_size=32000,
    min_frequency=0,)

# %%
files = [f'./data/raw_texts/{file}.txt' for file in ['collection_corpus', 'queries.train_corpus', 'queries.dev_corpus', 'queries.eval_corpus']]
wp_tokenizer.train(files=files, trainer=trainer)

# %%
wp_tokenizer.get_vocab()
# Out:
# {'scams': 29694,
#  'county': 1266,
#  '##roll': 2880,
#  'democrat': 17749,
#  'tate': 27420,
#  'ein': 11524,
#  'alter': 6240,
#  'ont': 7346,
#  'considerable': 12379,
#  '495': 25734,
#  'analyzed': 16510,
#  'bun': 8140,
#  'dishes': 8239,
#  'foreclosure': 14692,
#  'calcit': 31453,
#  '##var': 22310,
#  '##woods': 26307,
#  'material': 1747,
#  'nodule': 23099,
#  'appeared': 6539,
#  '##lobacter': 31909,
#  'sciences': 8548,
#  '##ister': 1879,
#  'espe': 2241,
#  'entity': 6834,
#  '##burgh': 8931,
#  'secrets': 14757,
#  'fault': 7164,
#  'weaker': 18923,
#  'eruptions': 16604,
#  '##dle': 2259,
#  'trent': 31698,
#  'engineered': 14259,
#  'flood': 6444,
#  '##asso': 21734,
#  'canadaâ': 26496,
#  '##rof': 8870,
#  'cowork': 28539,
#  '##ighth': 8928,
#  'potato': 6989,
#  'ness': 26226,
#  '##develop': 26022,
#  'secretly': 27925,
#  'amazon': 4493,
#  'phytopl': 31015,
#  'making': 1930,
#  '##ublic': 3646,
#  '##ridged': 20974,
#  'lor': 9641,
#  'yemen': 27699,
#  'educator': 18698,
#  'redes': 20541,
#  'san': 2618,
#  'lgbt': 25287,
#  'infancy': 24495,
#  'regulation': 7376,
#  'vagus': 23579,
#  'site': 2111,
#  'biscuit': 25755,
#  'schwann': 31362,
#  '##hythms': 21269,
#  'cm': 3325,
#  'used': 786,
#  'midline': 23188,
#  'encryption': 16802,
#  'certific': 4149,
#  'cipher': 31966,
#  'assessing': 17195,
#  'injured': 8403,
#  'springfield': 13855,
#  'story': 2868,
#  'deep': 2777,
#  'loud': 9730,
#  'dean': 12799,
#  'boston': 5888,
#  '##cooked': 24729,
#  'timeless': 25624,
#  'bentley': 29900,
#  'walk': 2685,
#  'pediatric': 8843,
#  '##ostasis': 15325,
#  '503': 28509,
#  'fac': 2074,
#  'ssid': 30848,
#  '##go': 2355,
#  'kc': 27366,
#  'app': 687,
#  'feel': 1917,
#  'cultural': 6042,
#  '\x80\x99.': 7112,
#  'productions': 18002,
#  '630': 19088,
#  '##aceae': 14392,
#  'decisions': 6717,
#  '￼': 250,
#  'moments': 12986,
#  'stockton': 27608,
#  'afferent': 22754,
#  'bye': 23767,
#  '##ping': 3948,
#  'random': 6479,
#  'ucl': 20945,
#  '+:': 21373,
#  '##uth': 18916,
#  'fewer': 7127,
#  '##union': 26738,
#  'musk': 18022,
#  'blended': 15049,
#  'apost': 15383,
#  'tailored': 20136,
#  'amal': 20321,
#  'sweating': 11119,
#  'randomized': 27505,
#  'deem': 13424,
#  'ssi': 15928,
#  'colloquial': 24757,
#  'sums': 28467,
#  'expressive': 28169,
#  'relief': 5946,
#  'tributary': 29509,
#  'butt': 6828,
#  'ureth': 9091,
#  'metronidazole': 28588,
#  'anglo': 13652,
#  'date': 1829,
#  'sprayed': 24249,
#  'sauces': 16037,
#  'key': 1895,
#  'meh': 28771,
#  'ballistic': 31746,
#  'tell': 2415,
#  'chipp': 31903,
#  '##iki': 14131,
#  'antide': 12225,
#  'walt': 9579,
#  'rheumat': 8995,
#  'inquiry': 15677,
#  'consumes': 21411,
#  'cares': 23234,
#  'knows': 7741,
#  'organ': 1248,
#  'murm': 25190,
#  '##wn': 976,
#  'affiliates': 22431,
#  'onâ': 25920,
#  '711': 29002,
#  'planes': 14834,
#  'bene': 1451,
#  'carbohydrate': 8190,
#  '118': 13479,
#  'gogg': 30037,
#  '##men': 6149,
#  'mechanic': 14271,
#  'stevia': 24730,
#  'nuclei': 13230,
#  'protozo': 23365,
#  'bermuda': 17077,
#  'commerce': 9042,
#  '##cr': 11874,
#  'fibula': 25244,
#  'aut': 1623,
#  'relays': 29971,
#  'taxp': 8007,
#  'tur': 2483,
#  'pythagorean': 18805,
#  'canvas': 15025,
#  'lcd': 16313,
#  'neonatal': 20790,
#  'oman': 24123,
#  '##will': 21600,
#  'dâ': 19988,
#  '##mal': 9709,
#  'validity': 15106,
#  '##iance': 9202,
#  'contaminated': 11067,
#  'compensate': 19595,
#  'do': 599,
#  'throb': 26898,
#  'contestant': 31114,
#  'defective': 17844,
#  'fiddle': 31193,
#  'majority': 4184,
#  '131': 17338,
#  '##ribed': 14902,
#  'bif': 16839,
#  '##othe': 17791,
#  'obligated': 27521,
#  'denomin': 13109,
#  'sourced': 24083,
#  '##ows': 992,
#  'deviations': 26147,
#  'prednis': 15912,
#  'caffe': 6031,
#  'hough': 22810,
#  'turb': 8737,
#  'profitable': 18373,
#  'empir': 16637,
#  '##ering': 3099,
#  'hypot': 15243,
#  'smel': 31993,
#  '##point': 5733,
#  'prolactin': 23629,
#  'extremities': 19427,
#  'paragraphs': 18984,
#  'cheet': 19280,
#  'californiaâ': 26138,
#  'error': 5425,
#  'piercing': 14739,
#  '617': 29959,
#  '##ories': 1438,
#  'palpitations': 19599,
#  'versions': 6590,
#  'occasionally': 7057,
#  'clement': 25336,
#  'financially': 20692,
#  'heat': 1796,
#  '##iot': 4572,
#  'disreg': 23541,
#  'folk': 10362,
#  'omp': 21392,
#  'honeymoon': 27778,
#  'ufc': 20842,
#  'berry': 13418,
#  '##kb': 23843,
#  '##cont': 5962,
#  'fas': 9264,
#  'wright': 13187,
#  'binocular': 30914,
#  'vasoconstrict': 31732,
#  'buns': 31861,
#  'paternity': 19938,
#  '##enerate': 22536,
#  'sanct': 18875,
#  'disease': 1374,
#  'costume': 19111,
#  '##inct': 3763,
#  'recipient': 10744,
#  'blockage': 12970,
#  'florida': 2891,
#  '##е': 449,
#  'confess': 27811,
#  'implantation': 15772,
#  'unrest': 22741,
#  'roth': 7324,
#  'accomplishments': 22611,
#  '##into': 30409,
#  'malaise': 30936,
#  '...):': 17572,
#  'sautã': 21927,
#  'vehicleâ': 27267,
#  'pluto': 15735,
#  'kindle': 9924,
#  'anatomical': 16788,
#  'till': 8549,
#  'retin': 15083,
#  'repeal': 18475,
#  '119': 14444,
#  'deoxyribonucleic': 23652,
#  'intolerance': 14238,
#  '.*': 15840,
#  'eyes': 3187,
#  'ther': 2424,
#  'fingern': 16836,
#  '##urst': 18739,
#  'fertilize': 22295,
#  '##uster': 13914,
#  'athletes': 9473,
#  'spawning': 27282,
#  'poker': 15744,
#  'yearsâ': 27536,
#  'carly': 30557,
#  'judith': 30925,
#  'navigating': 30838,
#  'sheep': 9049,
#  '##==': 7632,
#  'guest': 7588,
#  'moderation': 21264,
#  'flea': 13188,
#  'headers': 24857,
#  'commodity': 15221,
#  'rewarding': 18769,
#  '##anders': 20894,
#  'nder': 25149,
#  'helic': 12421,
#  '##col': 4405,
#  '##utical': 9892,
#  '737': 26888,
#  'hyperth': 15865,
#  'cds': 18136,
#  'raisins': 21485,
#  '##hyse': 18544,
#  'stocks': 9767,
#  'installer': 15919,
#  'solic': 16010,
#  'organizationâ': 23577,
#  '##holes': 31056,
#  'wettest': 17941,
#  'jetblue': 26695,
#  'flyer': 24349,
#  '##isserie': 28274,
#  'full': 1497,
#  'endeav': 28574,
#  '##gener': 23193,
#  'resil': 23684,
#  '925': 25138,
#  '##tp': 21291,
#  'must': 1264,
#  'read': 1283,
#  'dha': 24616,
#  'irons': 25168,
#  'strives': 28468,
#  'scrubbing': 29615,
#  'after': 884,
#  'electricity': 5257,
#  'epidural': 24305,
#  'vena': 18969,
#  'ß': 134,
#  'aust': 2395,
#  '##screen': 13656,
#  'proximal': 15165,
#  'tachy': 17335,
#  'rx': 18301,
#  'replication': 10545,
#  'politics': 9324,
#  'cirrhosis': 14942,
#  '##apes': 14980,
#  'addressing': 17006,
#  'foref': 20551,
#  'intolerant': 30654,
#  'deny': 19135,
#  'only': 894,
#  '##ore': 593,
#  'sound': 2764,
#  'headquarter': 13379,
#  '##poon': 5105,
#  '1902': 19422,
#  'pey': 22047,
#  '3â': 11419,
#  'docs': 22383,
#  'itunes': 6225,
#  'horrible': 20123,
#  'fã': 22625,
#  'scientifically': 23211,
#  'thrift': 30433,
#  'histogram': 31381,
#  'hogs': 31733,
#  'def': 850,
#  'detail': 3538,
#  'sevent': 9093,
#  'exclusively': 7822,
#  'rattlesn': 23726,
#  'vess': 3305,
#  '##ollen': 7261,
#  'soil': 2778,
#  'uni': 1394,
#  '##box': 4357,
#  '1993': 8407,
#  'peach': 14218,
#  'pictures': 5256,
#  'assem': 5276,
#  'painful': 5773,
#  'ir': 1641,
#  '##ancing': 8960,
#  'listeria': 29241,
#  'sug': 1502,
#  'value': 1751,
#  'ejaculation': 21477,
#  'cavern': 29239,
#  'statement': 3954,
#  'proceedings': 16372,
#  'validate': 27155,
#  'carri': 3533,
#  'script': 6423,
#  'list': 1085,
#  'visual': 4781,
#  'wel': 3713,
#  'inches': 2209,
#  'cater': 10692,
#  '##ffer': 3850,
#  'midw': 16332,
#  'ectopic': 22781,
#  'hoff': 23966,
#  'alta': 30758,
#  'caffeine': 6252,
#  'albumin': 15348,
#  'incremental': 27032,
#  'meantime': 24782,
#  'embassy': 16409,
#  'capabilities': 11018,
#  'engra': 19350,
#  'cherries': 19539,
#  'suspension': 9468,
#  'genoc': 31818,
#  'kauai': 30881,
#  'impacts': 13093,
#  'logs': 16347,
#  '\x94\x80': 24546,
#  'got': 2822,
#  '##ining': 1630,
#  'manufactures': 18211,
#  'bic': 10120,
#  'boroughs': 29614,
#  'predict': 6556,
#  'marcos': 31533,
#  'kos': 22544,
#  '##power': 10145,
#  'knights': 21093,
#  'telescopes': 31694,
#  '##idge': 2602,
#  'ipod': 9550,
#  '##olk': 19224,
#  '##port': 1406,
#  'carmel': 23449,
#  'absence': 8451,
#  'mcdonaldâ': 28471,
#  'transist': 22344,
#  'yan': 13545,
#  '##irm': 4308,
#  '##esia': 21233,
#  'occur': 1382,
#  'influencing': 26113,
#  '##oreg': 30202,
#  'adv': 1482,
#  'species': 2158,
#  'enjoys': 17405,
#  'subcutaneous': 17446,
#  'inhibitors': 13409,
#  '##ortion': 10149,
#  'seattle': 7442,
#  'superficial': 13312,
#  '##orrh': 8348,
#  'burgers': 17063,
#  'eugene': 20891,
#  'stressful': 18219,
#  'terrier': 15783,
#  'roku': 18558,
#  'designate': 20299,
#  'pontiac': 24371,
#  'nate': 31142,
#  'hiro': 21193,
#  'uploading': 28619,
#  'logic': 11509,
#  'entities': 10931,
#  'suppress': 12124,
#  'angiot': 22567,
#  '100â': 25390,
#  '##\x9e': 385,
#  '##ribution': 3395,
#  'economies': 17774,
#  'ibuprofen': 12700,
#  '##ushi': 15777,
#  'discipline': 11553,
#  'clogged': 19091,
#  '##adone': 20495,
#  'messaging': 15214,
#  'conferences': 23095,
#  'propeller': 29244,
#  '##aires': 19670,
#  'dexter': 20844,
#  'infused': 23186,
#  'rr': 14583,
#  '##chn': 11754,
#  'signaling': 19479,
#  'fou': 31999,
#  'mainly': 4794,
#  'hk': 31824,
#  'phara': 21097,
#  'kawasaki': 31917,
#  'effectively': 7555,
#  'undergraduate': 8136,
#  'branding': 24141,
#  'wilhelm': 28514,
#  'appreciate': 13450,
#  'duck': 7805,
#  '/-': 25592,
#  '154': 19953,
#  'reject': 9134,
#  'ica': 21879,
#  'papillomavirus': 27201,
#  '1996': 7410,
#  'gay': 9922,
#  'infilt': 19760,
#  'nitrate': 15378,
#  'epileptic': 31351,
#  'pines': 20987,
#  'laryngeal': 31932,
#  '##¯': 357,
#  'scaly': 21609,
#  '##conn': 9232,
#  'multip': 2324,
#  '##lbs': 17370,
#  'bree': 11941,
#  'desperate': 24067,
#  'thc': 14534,
#  'devi': 22479,
#  '##osteroids': 20829,
#  'powert': 29201,
#  'prohibits': 21641,
#  '##eas': 30280,
#  'tosh': 25562,
#  '453': 25428,
#  '##cal': 5048,
#  '##anumeric': 30681,
#  'testosterone': 8963,
#  '##âº': 12391,
#  'members': 2182,
#  'lichen': 20796,
#  'ah': 7829,
#  'hitch': 15621,
#  'refrigerator': 5630,
#  'impre': 23803,
#  '\x86': 76,
#  'bid': 7868,
#  '##ascript': 12655,
#  'mucosal': 28776,
#  'gall': 2669,
#  'before': 1134,
#  '##abil': 6092,
#  'relatives': 13399,
#  'tester': 25025,
#  '##comp': 19596,
#  'cams': 23561,
#  'agave': 26017,
#  'congressional': 11912,
#  'confron': 25752,
#  'marian': 25730,
#  'buff': 6786,
#  'verify': 8722,
#  '##ya': 6782,
#  '1851': 27805,
#  'wilkes': 28115,
#  'wp': 20065,
#  'enzym': 3705,
#  '090': 27156,
#  'sliding': 13806,
#  '##ase': 685,
#  '38â': 29473,
#  '##osper': 19889,
#  'rare': 3447,
#  'cable': 4195,
#  'diameters': 30823,
#  'tet': 7189,
#  'explo': 13675,
#  'prim': 1590,
#  'bleach': 9607,
#  'dop': 9158,
#  'overlay': 18680,
#  '##hole': 20033,
#  'b5': 31844,
#  'beef': 4239,
#  'veteran': 10704,
#  '##rome': 18859,
#  'interacts': 26021,
#  'spra': 15831,
#  'ecstasy': 28805,
#  'georget': 19826,
#  'pliers': 28758,
#  'liqu': 2519,
#  'inadequate': 16247,
#  'shortcuts': 20410,
#  'inuit': 30066,
#  'rins': 19989,
#  'check': 1368,
#  'ginger': 8699,
#  'oxy': 2407,
#  'îºï': 30626,
#  'lemon': 5672,
#  'mathematical': 12484,
#  '##oney': 1719,
#  'exclus': 4693,
#  'fotolia': 28349,
#  'engages': 23835,
#  'kreatif': 29997,
#  'laxatives': 26258,
#  '1916': 17463,
#  'nore': 18567,
#  'joey': 22427,
#  '##nect': 23935,
#  'polys': 14529,
#  'remot': 21547,
#  'unprot': 23418,
#  'tibetan': 28727,
#  'transact': 4650,
#  '172': 20962,
#  '##icut': 7910,
#  'foundation': 4980,
#  'helena': 27194,
#  'identity': 6323,
#  'sox': 21241,
#  '##nets': 28633,
#  'connecticut': 8268,
#  'junction': 10100,
#  'asteroids': 27570,
#  '##iox': 8226,
#  'except': 3873,
#  '##45': 9229,
#  'thresholds': 30678,
#  'stap': 7439,
#  'fiction': 9469,
#  'assure': 20356,
#  'pmp': 31019,
#  'monitored': 17552,
#  'unclear': 16214,
#  'crazy': 11741,
#  'flu': 1790,
#  '##gnosis': 16726,
#  'injector': 31027,
#  'noun': 2642,
#  'negotiating': 25984,
#  '##rusive': 18521,
#  'σ': 185,
#  'flashes': 15944,
#  'cred': 1489,
#  'cauliflower': 16648,
#  '##ussion': 15651,
#  '##rifice': 18017,
#  'enfor': 19634,
#  'corticosteroids': 21232,
#  'possible': 2060,
#  'steph': 7905,
#  'cephalexin': 31404,
#  'thesaurus': 7903,
#  'magazine': 6847,
#  '##apolis': 8741,
#  'recreation': 11247,
#  'pathology': 14140,
#  'narrow': 5232,
#  'itchy': 9490,
#  'ventura': 27603,
#  'tailor': 23675,
#  '##cht': 25277,
#  '##erge': 13575,
#  'salad': 7619,
#  'bonuses': 12366,
#  'disintegr': 24072,
#  'documents': 4381,
#  'hell': 6532,
#  'attained': 23813,
#  'cele': 3590,
#  'collaborate': 28186,
#  'steamboat': 31857,
#  'drow': 21142,
#  'headqu': 6515,
#  'traders': 19973,
#  '##eding': 2613,
#  'metabolized': 25221,
#  'depos': 3504,
#  'actresses': 20853,
#  'plank': 13696,
#  'cilantro': 21611,
#  'juices': 10413,
#  '##iddish': 28740,
#  'firing': 17285,
#  'brushing': 17517,
#  'kore': 6192,
#  '##eries': 8910,
#  'osh': 13174,
#  'handler': 21406,
#  '##ives': 1371,
#  'div': 2110,
#  'fiber': 3006,
#  'amplifier': 23373,
#  'parsons': 30473,
#  '##ile': 751,
#  'nodes': 7348,
#  'honored': 18464,
#  'respondents': 19440,
#  '##remia': 23926,
#  'sculpt': 14856,
#  'xbox': 7912,
#  'items': 3192,
#  'bell': 5579,
#  'sweeteners': 22006,
#  'font': 8506,
#  'anise': 24148,
#  'ew': 14356,
#  'cabo': 25297,
#  '286': 26817,
#  'binomial': 27061,
#  'attracting': 24996,
#  'stratified': 24553,
#  'uru': 23228,
#  'drilled': 25054,
#  'deco': 31782,
#  'diane': 22167,
#  'chihuahua': 25146,
#  'brewers': 29190,
#  'viewed': 9061,
#  '##vent': 4883,
#  'coag': 15634,
#  'anode': 24693,
#  '##elan': 26340,
#  'supervise': 26278,
#  '##woman': 18744,
#  'adhesion': 23694,
#  '##asis': 6621,
#  'isd': 29345,
#  'inkjet': 31359,
#  '##cross': 26737,
#  'vision': 4114,
#  'steal': 14566,
#  'fighter': 15686,
#  'binge': 22088,
#  'misc': 28374,
#  '##onge': 9221,
#  'barbara': 13378,
#  'artisan': 30540,
#  'trev': 25113,
#  'hudson': 12750,
#  'blueprint': 26446,
#  '##alis': 18280,
#  'designed': 2794,
#  'biopsy': 11748,
#  'scenic': 14482,
#  'hy': 1415,
#  '##buds': 30607,
#  'offenses': 18530,
#  'margins': 15458,
#  'gently': 7904,
#  '##stock': 11409,
#  'peers': 17116,
#  'decimals': 28531,
#  '##itation': 3282,
#  '##ipped': 5514,
#  'advisers': 30688,
#  'wounded': 19351,
#  'mercy': 19929,
#  'obtain': 3303,
#  'dust': 6356,
#  '##ized': 1270,
#  'ration': 25431,
#  '##oz': 5961,
#  'superst': 24761,
#  'reads': 13128,
#  'higher': 1922,
#  'brighton': 28909,
#  'dusk': 28623,
#  'module': 9744,
#  'replacing': 8361,
#  'britann': 17599,
#  '##bits': 8480,
#  'eighteen': 21377,
#  '##bek': 27334,
#  'claud': 19911,
#  'kinda': 24182,
#  'sincer': 31802,
#  'scholar': 15851,
#  'fidel': 17032,
#  '##mi': 6873,
#  'scul': 10555,
#  'delt': 23582,
#  '##bes': 8767,
#  'occl': 21932,
#  'gla': 9538,
#  'gastroesophageal': 23172,
#  '##câ': 23063,
#  'sending': 8973,
#  'challenge': 7679,
#  'surnames': 16365,
#  'lisa': 14379,
#  'silver': 4324,
#  'gw': 15945,
#  'gibb': 31336,
#  'dorothy': 24065,
#  'tach': 14741,
#  'coup': 2915,
#  'negotiations': 20203,
#  'carries': 6929,
#  'tar': 2953,
#  'sir': 6745,
#  'lunch': 8656,
#  'sour': 1520,
#  '##umble': 26483,
#  'tribune': 25968,
#  '1906': 19594,
#  'ja': 10596,
#  'produ': 849,
#  'windshield': 19075,
#  'ontario': 8492,
#  'practitioner': 10287,
#  'eyebrow': 27200,
#  'continents': 12984,
#  'genetics': 10735,
#  '10th': 10387,
#  'ceilings': 20003,
#  'governors': 21361,
#  '##milk': 19404,
#  'bost': 5832,
#  'antibacterial': 21708,
#  'quantify': 31675,
#  '##dled': 31075,
#  'artifact': 16886,
#  '##don': 15707,
#  'grained': 24523,
#  'carboxylic': 29849,
#  '##ingo': 30660,
#  'mozzarella': 22814,
#  'sectors': 15863,
#  'clots': 10613,
#  '##olytic': 16791,
#  'coded': 19499,
#  'cow': 5704,
#  'canine': 13765,
#  '30s': 21822,
#  'falling': 8074,
#  'allegedly': 21471,
#  '##aris': 26241,
#  'owner': 3999,
#  'cirrh': 14735,
#  'beau': 19598,
#  'sorry': 11043,
#  '##gers': 5997,
#  '##yin': 29430,
#  'dermatologist': 20448,
#  'door': 3737,
#  'happen': 5087,
#  'lé': 18795,
#  'dealt': 20380,
#  'melan': 8886,
#  'retract': 21130,
#  'prerequisites': 28271,
#  'inherited': 8875,
#  'recent': 3312,
#  'seren': 30590,
#  'spanning': 18772,
#  'desktop': 6136,
#  '##\x89': 380,
#  '##ateral': 7971,
#  '##isâ': 30941,
#  'competitions': 23322,
#  '##acter': 1239,
#  'downside': 27931,
#  'administr': 4660,
#  'sender': 19085,
#  'evalu': 8125,
#  '##acs': 23908,
#  'leaked': 29392,
#  'misunderstood': 26461,
#  'tad': 18213,
#  'rot': 3304,
#  'triang': 6059,
#  'prair': 13524,
#  'rally': 17946,
#  'railway': 12171,
#  'rouge': 19076,
#  '##ific': 892,
#  'sigmoid': 27118,
#  '332': 27379,
#  '##pc': 21127,
#  'israeli': 20297,
#  'crossword': 17034,
#  'cate': 21985,
#  'alan': 13932,
#  'ka': 8825,
#  'necklace': 22120,
#  'scheduling': 16678,
#  '##........': 3138,
#  'chak': 19836,
#  '____': 19307,
#  'ulcers': 9461,
#  'aforementioned': 30865,
#  '##oque': 22028,
#  'heterogeneous': 25788,
#  'wheat': 6143,
#  'gor': 8084,
#  'missions': 15472,
#  'nursing': 3905,
#  'acceptable': 9768,
#  'hard': 1614,
#  'bacter': 1969,
#  '##rol': 6594,
#  '1999': 6775,
#  'anaheim': 23347,
#  'votes': 4448,
#  'yel': 25587,
#  'giov': 31546,
#  'jumbo': 22968,
#  'driver': 3644,
#  'malfunction': 21624,
#  'renewals': 31704,
#  'diarr': 4913,
#  'ripp': 24161,
#  '##rosse': 22614,
#  'rushing': 28397,
#  'undoub': 24541,
#  'imminent': 27341,
#  'formaldehyde': 24226,
#  'unused': 18414,
#  'rns': 22511,
#  '##givers': 19588,
#  'miranda': 22008,
#  'temporal': 13478,
#  'competitive': 7396,
#  'joists': 23272,
#  'sleeps': 28068,
#  '##nutrition': 21182,
#  'skiing': 18194,
#  'mothers': 12576,
#  'tak': 19243,
#  'italic': 24066,
#  '##ό': 429,
#  'biography': 9690,
#  'denial': 19806,
#  '##ounsaturated': 21473,
#  'arterioles': 31039,
#  '3k': 31585,
#  'touching': 13149,
#  'mitochond': 8818,
#  'intrusion': 28057,
#  '##22': 6808,
#  'flair': 28568,
#  'preservation': 16151,
#  'tag': 4906,
#  '747': 24381,
#  'lesbian': 27588,
#  'emerges': 25830,
#  '##open': 25805,
#  'predominant': 20964,
#  'conversation': 10661,
#  'cracks': 13267,
#  'vlad': 22349,
#  'gardner': 25531,
#  'cadmium': 31542,
#  'genu': 12065,
#  'plexus': 18804,
#  '##blo': 17146,
#  'yields': 12841,
#  '##rim': 4408,
#  '##yph': 21656,
#  'garages': 26752,
#  'mad': 4420,
#  'taskbar': 19190,
#  'strict': 7916,
#  'acad': 3561,
#  '##yled': 28120,
#  'mansfield': 31545,
#  'ari': 4540,
#  '##liers': 11824,
#  'megaw': 31891,
#  '##atri': 26880,
#  '##now': 9521,
#  'mer': 2838,
#  'introduced': 4957,
#  'endpoint': 26445,
#  '##oman': 11340,
#  'tray': 10858,
#  'sustainable': 13241,
#  'vacuole': 24324,
#  'intl': 26661,
#  'parenth': 15385,
#  'sickness': 12290,
#  'silvery': 24929,
#  'comparable': 11930,
#  'butcher': 22334,
#  'pecan': 28457,
#  'bened': 21884,
#  '##tery': 9085,
#  'guatemala': 17654,
#  'ambition': 30567,
#  'triangular': 16570,
#  'rhombus': 30536,
#  'colorless': 14215,
#  'shaping': 21173,
#  '##opes': 8309,
#  'lore': 25855,
#  'intrinsic': 16028,
#  '815': 31890,
#  'drawing': 7686,
#  '11â': 23491,
#  'pratt': 27833,
#  'vehicles': 4983,
#  'kent': 5957,
#  'thal': 23011,
#  '##pective': 31982,
#  'typically': 2006,
#  'weaving': 26382,
#  '##style': 19758,
#  'youtu': 28768,
#  'servicem': 31052,
#  'berm': 14821,
#  'bicycles': 29945,
#  'offense': 10547,
#  '##leading': 16737,
#  'taxonomic': 24277,
#  'hiding': 18046,
#  '##ri': 578,
#  '41': 4362,
#  '##ridge': 10191,
#  'participates': 28299,
#  'menâ': 18023,
#  'depreci': 31401,
#  'catholic': 9413,
#  'golgi': 19765,
#  'hypertrophy': 26667,
#  'abundant': 8887,
#  'ld': 8773,
#  '##iga': 17118,
#  'tastes': 12930,
#  '##mc': 16183,
#  'bottom': 2885,
#  ...}

# %%
wp_tokenizer.encode('Hi i am a studen. My name is Hai.').ids
# Out:
# [1, 4772, 49, 663, 41, 1035, 472, 16, 886, 857, 490, 31813, 16, 2]

# %%
wp_tokenizer.decode([1, 4772, 49, 663, 41, 1035, 472, 16, 886, 857, 490, 579, 257, 16, 2])
# Out:
# 'hi i am a studen. my name is hab.'

# %%
wp_tokenizer.save('./save/tokenizer/wp_tokenizer_32k.json', True)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# c:\Users\thanh\OneDrive\Desktop\20231\Deep Learing\DeepLearning20231\train_tokenizer\tokenizer.ipynb Cell 20 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/thanh/OneDrive/Desktop/20231/Deep%20Learing/DeepLearning20231/train_tokenizer/tokenizer.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> wp_tokenizer.save('./save/tokenizer/wp_tokenizer_32k.json', True)
#
# Exception: The system cannot find the path specified. (os error 3)

# %% [markdown]
# ### Unigram tokenizer

# %%
unigram_tokenizer = Tokenizer(models.Unigram())

trainer = trainers.UnigramTrainer(special_tokens=[
    '[UNK]',
    '[CLS]',
    '[SEP]',
    '[PAD]'],
    unk_token='[UNK]',
    vocab_size=32000,
    min_frequency=0)
unigram_tokenizer.pre_tokenizer = pre_tokenizers.ByteLevel()

# %%
files = [f'./data/raw_texts/{file}.txt' for file in ['collection_corpus', 'queries.train_corpus', 'queries.dev_corpus', 'queries.eval_corpus']]
unigram_tokenizer.train(files=files, trainer=trainer)

# %%
unigram_tokenizer.__dir__()
# Out:
# ['__new__',
#  '__getstate__',
#  '__setstate__',
#  '__getnewargs__',
#  'from_str',
#  'from_file',
#  'from_buffer',
#  'from_pretrained',
#  'to_str',
#  'save',
#  'num_special_tokens_to_add',
#  'get_vocab',
#  'get_vocab_size',
#  'enable_truncation',
#  'no_truncation',
#  'enable_padding',
#  'no_padding',
#  'encode',
#  'encode_batch',
#  'decode',
#  'decode_batch',
#  'token_to_id',
#  'id_to_token',
#  'add_tokens',
#  'add_special_tokens',
#  'train',
#  'train_from_iterator',
#  'post_process',
#  'truncation',
#  'post_processor',
#  'decoder',
#  'pre_tokenizer',
#  'padding',
#  'model',
#  'normalizer',
#  '__dict__',
#  '__doc__',
#  '__module__',
#  '__repr__',
#  '__hash__',
#  '__str__',
#  '__getattribute__',
#  '__setattr__',
#  '__delattr__',
#  '__lt__',
#  '__le__',
#  '__eq__',
#  '__ne__',
#  '__gt__',
#  '__ge__',
#  '__init__',
#  '__reduce_ex__',
#  '__reduce__',
#  '__subclasshook__',
#  '__init_subclass__',
#  '__format__',
#  '__sizeof__',
#  '__dir__',
#  '__class__']

# %%
unigram_tokenizer.encode('Hi, my name is Hai')
# Out:
# Encoding(num_tokens=10, attributes=[ids, type_ids, tokens, offsets, attention_mask, special_tokens_mask, overflowing])

# %%
from transformers.tokenization_utils import PreTrainedTokenizer

# %% [markdown]
# ## SentencePiece tokenizer

# %% [markdown]
# ### BPE tokenizer

# %%
files = [f'./data/raw_texts/{file}.txt' for file in ['collection_corpus', 'queries.train_corpus', 'queries.dev_corpus', 'queries.eval_corpus']]
spm.SentencePieceTrainer.Train(
    input=files,
    model_prefix='./save/tokenizer/spModel_bpe_8k.model',
    vocab_size=32000,
    pad_id=0,                
    unk_id=1,
    bos_id=2,
    eos_id=3,
    pad_piece='[PAD]',
    unk_piece='[UNK]',
    bos_piece='[CLS]',
    eos_piece='[SEP]',
    user_defined_symbols='[MASK]',
    model_type='bpe'
)
sp = spm.SentencePieceProcessor()
sp.load('spModel.model')

# %%
sp.encode_as_pieces('Hi i am a student, my name is Hai')
# Out:
# ['▁Hi', '▁i', '▁am', '▁a', '▁student', ',', '▁my', '▁name', '▁is', '▁H', 'ai']

# %% [markdown]
# ### Unigram tokenizer

# %%
files = [f'./data/raw_texts/{file}.txt' for file in ['collection_corpus', 'queries.train_corpus', 'queries.dev_corpus', 'queries.eval_corpus']]
spm.SentencePieceTrainer.Train(
    input=files,
    model_prefix='./save/tokenizer/spModel_bpe_8k.model',
    vocab_size=32000,
    pad_id=0,                
    unk_id=1,
    bos_id=2,
    eos_id=3,
    pad_piece='[PAD]',
    unk_piece='[UNK]',
    bos_piece='[CLS]',
    eos_piece='[SEP]',
    user_defined_symbols='[MASK]',
    model_type='uni'
)
sp = spm.SentencePieceProcessor()
sp.load('spModel.model')
